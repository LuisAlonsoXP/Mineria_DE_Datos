# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisAlonsoXP/Mineria_DE_Datos/blob/main/mineria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de Datos

# %% [markdown]
# ## Primer Parcial

# %% [markdown]
# ### 1.1 Introduccion

# %% [markdown]
# ### 1.1.1 Conceptos

# %% [markdown]
# ¿Qué es la minería de datos?
#
# La minería de datos es el uso del machine learning y el análisis estadístico para descubrir patrones y otra información valiosa de grandes conjuntos de datos.

# %% [markdown]
# ### 1.1.2 Ciencia de datos

# %% [markdown]
# ¿Qué es la ciencia de datos?
#
# La ciencia de datos es un campo que combina las matemáticas y la estadística, la programación especializada, los analytics avanzados, la inteligencia artificial IA y el machine learning con conocimientos específicos en la materia para descubrir insights procesables ocultos en los datos de una organización. Estos insights pueden utilizarse para orientar la toma de decisiones y la planificación estratégica.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
my_list = [1, 2, 3]
len(my_list)
# Out:
# 3

# %%
L = [1, 2, 3]
L.insert(3,4)
len(L)
# Out:
# 4

# %%
a = 2
def square(a):
 return a ** 2

square(a)
# Out:
# 4

# %% [markdown]
# IPython Magic Commands

# %%
# el comando magico %timeit sirve para evaluar el desempeño en terminos de tiempo
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 70.8 µs ± 1.38 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# El comando magico %%timeit sirve tambie para evaluar el desempeño
# solo que este abarca varias lineas de codigo en lugar de una
# %%timeit
L = []
for n in range(1000):
  L.append(n ** 2)
# Out:
# 79.8 µs ± 4.04 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit?

# %%
# %%timeit?

# %% [markdown]
# IPython and Shell Commands

# %%
#ver la ruta donde estas
# !ls
# Out:
# sample_data

# %%
# con cd te mueves a la ruta especificada
# %cd sample_data/
# Out:
# /content/sample_data

# %%
#ver la ruta pero con % mas tiempo
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# !cat
# Out:
# ^C

# %%
# %env
# Out:
# {'SHELL': '/bin/bash',
#  'COLAB_JUPYTER_TRANSPORT': 'ipc',
#  'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events',
#  'VM_GCE_METADATA_HOST': '169.254.169.253',
#  'MODEL_PROXY_HOST': 'https://mp.kaggle.net',
#  'HOSTNAME': 'be3e97503cdb',
#  'LANGUAGE': 'en_US',
#  'TBE_RUNTIME_ADDR': '172.28.0.1:8011',
#  'GCE_METADATA_TIMEOUT': '3',
#  'COLAB_JUPYTER_IP': '172.28.0.12',
#  'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/',
#  'KMP_LISTEN_PORT': '6000',
#  'TF_FORCE_GPU_ALLOW_GROWTH': 'true',
#  'ENV': '/root/.bashrc',
#  'PWD': '/',
#  'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009',
#  'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s',
#  'TBE_CREDS_ADDR': '172.28.0.1:8008',
#  'COLAB_JUPYTER_TOKEN': '<hidden>',
#  'LAST_FORCED_REBUILD': '20250623',
#  'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20',
#  'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12',
#  'UV_BUILD_CONSTRAINT': '',
#  'COLAB_WARMUP_DEFAULTS': '1',
#  'HOME': '/root',
#  'LANG': 'en_US.UTF-8',
#  'CLOUDSDK_CONFIG': '/content/.config',
#  'UV_SYSTEM_PYTHON': 'true',
#  'COLAB_RELEASE_TAG': 'release-colab-external_20260120-060051_RC00',
#  'KMP_TARGET_PORT': '9000',
#  'KMP_EXTRA_ARGS': '--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-2gu7okw4sp101 --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true ',
#  'UV_INSTALL_DIR': '/usr/local/bin',
#  'COLAB_LANGUAGE_SERVER_PROXY_LSP_DIRS': '/datalab/web/pyright/typeshed-fallback/stdlib,/usr/local/lib/python3.10/dist-packages',
#  'COLAB_KERNEL_MANAGER_PROXY_PORT': '6000',
#  'CLOUDSDK_PYTHON': 'python3',
#  'NO_GCE_CHECK': 'False',
#  'PYTHONPATH': '/env/python',
#  'SHLVL': '0',
#  'COLAB_LANGUAGE_SERVER_PROXY': '/usr/colab/bin/language_service',
#  'UV_CONSTRAINT': '',
#  'PYTHONUTF8': '1',
#  'COLAB_GPU': '',
#  'GCS_READ_CACHE_BLOCK_SIZE_MB': '16',
#  'LC_ALL': 'en_US.UTF-8',
#  'COLAB_FILE_HANDLER_ADDR': 'localhost:3453',
#  'PATH': '/opt/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin',
#  'COLAB_IMAGE_TYPE': 'cpu',
#  'COLAB_DEBUG_ADAPTER_MUX_PATH': '/usr/local/bin/dap_multiplexer',
#  'PYTHONWARNINGS': 'ignore:::pip._internal.cli.base_command',
#  'DEBIAN_FRONTEND': 'noninteractive',
#  'COLAB_BACKEND_VERSION': 'next',
#  'OLDPWD': '/',
#  '_PYVIZ_COMMS_INSTALLED': '1',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'JPY_SESSION_NAME': 'https://github.com/LuisAlonsoXP/Mineria_DE_Datos/blob/main/Mineria.ipynb',
#  'JPY_PARENT_PID': '92',
#  'TERM': 'xterm-color',
#  'CLICOLOR': '1',
#  'PAGER': 'cat',
#  'GIT_PAGER': 'cat',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#  'ENABLE_DIRECTORYPREFETCHER': '1',
#  'USE_AUTH_EPHEM': '1',
#  'COLAB_NOTEBOOK_ID': 'https://github.com/LuisAlonsoXP/Mineria_DE_Datos/blob/main/Mineria.ipynb'}

# %% [markdown]
# Understanding Data Types in Python

# %%
import numpy as np

# %%
# lista entera
np.array([1, 4, 2, 5, 3])
# Out:
# array([1, 4, 2, 5, 3])

# %%
np.array([3.14, 4, 2, 3])
# Out:
# array([3.14, 4.  , 2.  , 3.  ])

# %%
np.array([1, 2, 3, 4], dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
np.array([1, 2, 3, 4], dtype='int')
# Out:
# array([1, 2, 3, 4])

# %%
# rangos
np.array([range(i, i + 3) for i in [2, 4, 6]])
# Out:
# array([[2, 3, 4],
#        [4, 5, 6],
#        [6, 7, 8]])

# %% [markdown]
# The Basics of NumPy Arrays

# %%
import numpy as np
np.random.seed(0)  #semilla random

x1 = np.random.randint(10, size=6)  # array de una dimension
x2 = np.random.randint(10, size=(3, 4))  # array de dos dimensiones
x3 = np.random.randint(10, size=(3, 4, 5))  # array de tres dimensiones

# %%
print("x3 ndim: ", x3.ndim) # la propiedad ndim nos dice el numero de dimensiones
print("x3 shape:", x3.shape) # shape dimesiones
print("x3 size: ", x3.size) # tamaño se multiplican los numeros ej  size=(3, 4, 5)
# Out:
# x3 ndim:  3
# x3 shape: (3, 4, 5)
# x3 size:  60

# %%
print("dtype:", x3.dtype) #tipo de dato
# Out:
# dtype: int64

# %%
print("itemsize:", x3.itemsize, "bytes") #tamaño de bytes
print("nbytes:", x3.nbytes, "bytes") # numero de bytes
# Out:
# itemsize: 8 bytes
# nbytes: 480 bytes

# %% [markdown]
# Array Indexing: Accessing Single Elements

# %%
x1
# Out:
# array([5, 0, 3, 3, 7, 9])

# %%
x1[0] # Colocamon el indice del elemento a extraer en este caso el primer elemento tiene el indice 0
# Out:
# np.int64(5)

# %%
x1[4]
# Out:
# np.int64(7)

# %%
x1[-1] # Nos regresa el ultimo elemento de ndarray va de 0 hacai atras
# Out:
# np.int64(9)

# %%
x1[-2]
# Out:
# np.int64(7)

# %%
x2
# Out:
# array([[3, 5, 2, 4],
#        [7, 6, 8, 8],
#        [1, 6, 7, 7]])

# %%
x2[0, 0]
# Out:
# np.int64(3)

# %%
x2[2, 0]
# Out:
# np.int64(1)

# %%
x2[2, -1]
# Out:
# np.int64(7)

# %%
x2[0,2]
# Out:
# np.int64(2)

# %%
x2[0, 0] = 12 # para modificar un valor en una ubicacion en especifico por otro
x2
# Out:
# array([[12,  5,  2,  4],
#        [ 7,  6,  8,  8],
#        [ 1,  6,  7,  7]])

# %% [markdown]
# ### 1.2 Analisis Estadistico

# %% [markdown]
# #### Estadistica Basica

# %% [markdown]
# Media (Mean)

# %%
data = np.array([1, 2, 3, 4, 5])
media = np.mean(data)
print(media)
# Out:
# 3.0

# %% [markdown]
# Promedio (Average) y Promedio Ponderado

# %%
data = np.array([1, 2, 3, 4, 5])
weights = np.array([1, 2, 3, 4, 5])
promedio = np.average(data)
promedio_ponderado = np.average(data, weights=weights)

# %%
print(promedio)
print(promedio_ponderado)
# Out:
# 3.0
# 3.6666666666666665

# %% [markdown]
# Mediana

# %%
mediana = np.median(data)

# %%
print(mediana)
# Out:
# 3.0

# %% [markdown]
# Varianza y Desviación Estándar

# %%
varianza = np.var(data)
desviacion = np.std(data)

# %%
print(varianza)
print(desviacion)
# Out:
# 2.0
# 1.4142135623730951

# %% [markdown]
# Generación de Datos Aleatorios

# %%
muestra = np.random.normal(0, 1, 1000)
print(np.mean(muestra), np.std(muestra))
# Out:
# -0.006543456960417206 1.0059985778093545

# %% [markdown]
# Correlación

# %%
corr = np.corrcoef([1,2,3], [1,5,7])

# %%
print(corr)
# Out:
# [[1.         0.98198051]
#  [0.98198051 1.        ]]

# %% [markdown]
# ### 1.2.1 Cuadros y Graficas Estadisticos

# %% [markdown]
# Cuadros Estadisticos

# %%
import numpy as np
import pandas as pd
from io import StringIO

# %%
raw = """Marca temporal\tNúmero de matrícula\t¿Cuántos años cumplidos tienes?\t¿Has realizado programas utilizando Python?\t¿Has utilizado Google Colab?\t¿Tienes cuenta de GitHub?
19/01/2026 18:32:18\t178920\t22\tSi\tNo\tSi
19/01/2026 18:32:23\t182712\t21\tSi\tNo\tSi
19/01/2026 18:32:25\t180370\t26\tSi\tSi\tSi
19/01/2026 18:32:27\t182570\t21\tSi\tSi\tSi
19/01/2026 18:32:28\t177622\t24\tSi\tNo\tSi
19/01/2026 18:32:29\t175166\t22\tSi\tSi\tSi
19/01/2026 18:32:30\t177573\t22\tSi\tSi\tSi
19/01/2026 18:32:35\t178430\t21\tSi\tSi\tSi
19/01/2026 18:32:38\t179169\t23\tSi\tNo\tSi
19/01/2026 18:32:41\t177263\t22\tSi\tSi\tSi
19/01/2026 18:32:48\t179884\t23\tSi\tNo\tSi
19/01/2026 18:32:48\t183016\t22\tSi\tNo\tSi
19/01/2026 18:32:50\t179033\t23\tSi\tSi\tNo
19/01/2026 18:32:54\t178218\t22\tSi\tNo\tSi
19/01/2026 18:32:55\t178446\t22\tSi\tSi\tSi
19/01/2026 18:33:00\t178166\t22\tSi\tSi\tNo
19/01/2026 18:33:02\t177406\t22\tSi\tNo\tSi
19/01/2026 18:33:05\t177192\t22\tSi\tSi\tSi
19/01/2026 18:33:08\t182451\t21\tSi\tNo\tSi
19/01/2026 18:33:08\t171513\t24\tNo\tNo\tSi
19/01/2026 18:33:09\t181619\t21\tSi\tNo\tSi
19/01/2026 18:33:12\t182298\t23\tSi\tNo\tSi
19/01/2026 18:33:14\t181419\t24\tNo\tNo\tSi
19/01/2026 18:33:32\t177291\t21\tSi\tSi\tSi
19/01/2026 18:33:42\t182085\t22\tSi\tNo\tSi
19/01/2026 18:33:53\t176453\t22\tSi\tNo\tSi
19/01/2026 18:34:04\t176263\t24\tSi\tNo\tSi
19/01/2026 18:34:06\t179997\t21\tSi\tNo\tSi
19/01/2026 18:36:21\t175842\t23\tSi\tNo\tNo
19/01/2026 20:19:21\t179913\t20\tSi\tNo\tSi
19/01/2026 20:19:48\t177301\t22\tSi\tSi\tNo
19/01/2026 20:20:06\t183060\t21\tSi\tNo\tSi
19/01/2026 20:20:08\t177935\t22\tSi\tSi\tSi
19/01/2026 20:20:19\t177700\t20\tSi\tSi\tSi
19/01/2026 20:20:26\t178318\t24\tSi\tSi\tSi
19/01/2026 20:20:27\t174653\t24\tSi\tNo\tSi
19/01/2026 20:20:29\t177139\t21\tSi\tNo\tSi
19/01/2026 20:20:31\t173479\t25\tSi\tNo\tNo
19/01/2026 20:20:39\t175588\t23\tNo\tNo\tSi
19/01/2026 20:20:45\t178774\t23\tSi\tSi\tSi
19/01/2026 20:20:45\t175031\t23\tSi\tNo\tNo
19/01/2026 20:20:49\t178396\t21\tSi\tSi\tSi
19/01/2026 20:20:49\t172068\t23\tNo\tNo\tNo
19/01/2026 20:20:50\t174197\t23\tNo\tNo\tSi
19/01/2026 20:20:55\t178584\t22\tSi\tNo\tSi
19/01/2026 20:20:55\t175329\t24\tSi\tNo\tSi
19/01/2026 20:20:56\t177685\t22\tSi\tSi\tSi
19/01/2026 20:20:57\t178678\t22\tNo\tNo\tSi
19/01/2026 20:21:04\t177143\t22\tSi\tNo\tSi
19/01/2026 20:21:07\t182318\t26\tSi\tNo\tSi
19/01/2026 20:21:27\t182377\t20\tSi\tNo\tSi
19/01/2026 20:21:34\t179419\t22\tSi\tNo\tNo
19/01/2026 20:21:35\t181662\t21\tSi\tNo\tSi
19/01/2026 20:21:38\t181760\t21\tSi\tNo\tSi
19/01/2026 20:22:06\t177888\t22\tSi\tNo\tSi
19/01/2026 20:22:15\t176535\t25\tSi\tNo\tSi
19/01/2026 20:22:29\t179862\t21\tSi\tNo\tSi
19/01/2026 20:22:32\t178378\t22\tSi\tNo\tSi
19/01/2026 20:22:50\t177451\t22\tSi\tNo\tSi
19/01/2026 20:23:15\t179804\t21\tSi\tNo\tSi
"""

# Cargar datos
df = pd.read_csv(StringIO(raw), sep='\t')
df.columns = [c.strip() for c in df.columns]

# Variables
df['edad'] = pd.to_numeric(df['¿Cuántos años cumplidos tienes?'], errors='coerce')
map_sn = {'Si': True, 'No': False}
df['prog_python'] = df['¿Has realizado programas utilizando Python?'].map(map_sn)
df['usa_colab'] = df['¿Has utilizado Google Colab?'].map(map_sn)
df['cuenta_github'] = df['¿Tienes cuenta de GitHub?'].map(map_sn)

# A NumPy
edad = df['edad'].to_numpy(dtype=float)
prog_py = df['prog_python'].to_numpy(dtype=bool)
usa_colab = df['usa_colab'].to_numpy(dtype=bool)
cuenta_gh = df['cuenta_github'].to_numpy(dtype=bool)

# Descriptivos de edad (NumPy)
summary_age = {
    'n': int(edad.size),
    'min': float(np.min(edad)),
    'p25': float(np.percentile(edad, 25)),
    'mediana': float(np.median(edad)),
    'media': float(np.mean(edad)),
    'p75': float(np.percentile(edad, 75)),
    'max': float(np.max(edad)),
    'rango(ptp)': float(np.ptp(edad)),
    'var_muestral': float(np.var(edad, ddof=1)),
    'std_muestral': float(np.std(edad, ddof=1)),
    'cv': float(np.std(edad, ddof=1)/np.mean(edad)),
}

# Frecuencias (NumPy)
freq_python = {'Si': int(np.count_nonzero(prog_py)), 'No': int(edad.size - np.count_nonzero(prog_py))}
freq_colab  = {'Si': int(np.count_nonzero(usa_colab)), 'No': int(edad.size - np.count_nonzero(usa_colab))}
freq_gh     = {'Si': int(np.count_nonzero(cuenta_gh)), 'No': int(edad.size - np.count_nonzero(cuenta_gh))}

# Tablas cruzadas (NumPy)
def tabla2x2(a, b):
    t = np.zeros((2,2), dtype=int)
    t[1,1] = np.count_nonzero(a & b)
    t[1,0] = np.count_nonzero(a & ~b)
    t[0,1] = np.count_nonzero(~a & b)
    t[0,0] = np.count_nonzero(~a & ~b)
    return t

tab_py_colab = tabla2x2(prog_py, usa_colab)
tab_py_gh    = tabla2x2(prog_py, cuenta_gh)
tab_colab_gh = tabla2x2(usa_colab, cuenta_gh)

# Medias de edad por grupo (NumPy)
means_by_group = {
    'edad_promedio_Python': {'Si': float(np.mean(edad[prog_py])) if np.any(prog_py) else np.nan,
                             'No': float(np.mean(edad[~prog_py])) if np.any(~prog_py) else np.nan},
    'edad_promedio_Colab':  {'Si': float(np.mean(edad[usa_colab])) if np.any(usa_colab) else np.nan,
                             'No': float(np.mean(edad[~usa_colab])) if np.any(~usa_colab) else np.nan},
    'edad_promedio_GitHub': {'Si': float(np.mean(edad[cuenta_gh])) if np.any(cuenta_gh) else np.nan,
                             'No': float(np.mean(edad[~cuenta_gh])) if np.any(~cuenta_gh) else np.nan},
}

summary_age, freq_python, freq_colab, freq_gh, tab_py_colab, tab_py_gh, tab_colab_gh, means_by_group
# Out:
# ({'n': 60,
#   'min': 20.0,
#   'p25': 21.0,
#   'mediana': 22.0,
#   'media': 22.3,
#   'p75': 23.0,
#   'max': 26.0,
#   'rango(ptp)': 6.0,
#   'var_muestral': 1.8406779661016948,
#   'std_muestral': 1.3567158752302173,
#   'cv': 0.06083927691615324},
#  {'Si': 54, 'No': 6},
#  {'Si': 18, 'No': 42},
#  {'Si': 52, 'No': 8},
#  array([[ 6,  0],
#         [36, 18]]),
#  array([[ 1,  5],
#         [ 7, 47]]),
#  array([[ 5, 37],
#         [ 3, 15]]),
#  {'edad_promedio_Python': {'Si': 22.203703703703702, 'No': 23.166666666666668},
#   'edad_promedio_Colab': {'Si': 22.11111111111111, 'No': 22.38095238095238},
#   'edad_promedio_GitHub': {'Si': 22.21153846153846, 'No': 22.875}})

# %%
df
# Out:
#          Marca temporal  Número de matrícula  ¿Cuántos años cumplidos tienes?  \
# 0   19/01/2026 18:32:18               178920                               22
# 1   19/01/2026 18:32:23               182712                               21
# 2   19/01/2026 18:32:25               180370                               26
# 3   19/01/2026 18:32:27               182570                               21
# 4   19/01/2026 18:32:28               177622                               24
# 5   19/01/2026 18:32:29               175166                               22
# 6   19/01/2026 18:32:30               177573                               22
# 7   19/01/2026 18:32:35               178430                               21
# 8   19/01/2026 18:32:38               179169                               23
# 9   19/01/2026 18:32:41               177263                               22
# 10  19/01/2026 18:32:48               179884                               23
# 11  19/01/2026 18:32:48               183016                               22
# 12  19/01/2026 18:32:50               179033                               23
# 13  19/01/2026 18:32:54               178218                               22
# 14  19/01/2026 18:32:55               178446                               22
# 15  19/01/2026 18:33:00               178166                               22
# 16  19/01/2026 18:33:02               177406                               22
# 17  19/01/2026 18:33:05               177192                               22
# 18  19/01/2026 18:33:08               182451                               21
# 19  19/01/2026 18:33:08               171513                               24
# 20  19/01/2026 18:33:09               181619                               21
# 21  19/01/2026 18:33:12               182298                               23
# 22  19/01/2026 18:33:14               181419                               24
# 23  19/01/2026 18:33:32               177291                               21
# 24  19/01/2026 18:33:42               182085                               22
# 25  19/01/2026 18:33:53               176453                               22
# 26  19/01/2026 18:34:04               176263                               24
# 27  19/01/2026 18:34:06               179997                               21
# 28  19/01/2026 18:36:21               175842                               23
# 29  19/01/2026 20:19:21               179913                               20
# 30  19/01/2026 20:19:48               177301                               22
# 31  19/01/2026 20:20:06               183060                               21
# 32  19/01/2026 20:20:08               177935                               22
# 33  19/01/2026 20:20:19               177700                               20
# 34  19/01/2026 20:20:26               178318                               24
# 35  19/01/2026 20:20:27               174653                               24
# 36  19/01/2026 20:20:29               177139                               21
# 37  19/01/2026 20:20:31               173479                               25
# 38  19/01/2026 20:20:39               175588                               23
# 39  19/01/2026 20:20:45               178774                               23
# 40  19/01/2026 20:20:45               175031                               23
# 41  19/01/2026 20:20:49               178396                               21
# 42  19/01/2026 20:20:49               172068                               23
# 43  19/01/2026 20:20:50               174197                               23
# 44  19/01/2026 20:20:55               178584                               22
# 45  19/01/2026 20:20:55               175329                               24
# 46  19/01/2026 20:20:56               177685                               22
# 47  19/01/2026 20:20:57               178678                               22
# 48  19/01/2026 20:21:04               177143                               22
# 49  19/01/2026 20:21:07               182318                               26
# 50  19/01/2026 20:21:27               182377                               20
# 51  19/01/2026 20:21:34               179419                               22
# 52  19/01/2026 20:21:35               181662                               21
# 53  19/01/2026 20:21:38               181760                               21
# 54  19/01/2026 20:22:06               177888                               22
# 55  19/01/2026 20:22:15               176535                               25
# 56  19/01/2026 20:22:29               179862                               21
# 57  19/01/2026 20:22:32               178378                               22
# 58  19/01/2026 20:22:50               177451                               22
# 59  19/01/2026 20:23:15               179804                               21
#
#    ¿Has realizado programas utilizando Python? ¿Has utilizado Google Colab?  \
# 0                                           Si                           No
# 1                                           Si                           No
# 2                                           Si                           Si
# 3                                           Si                           Si
# 4                                           Si                           No
# 5                                           Si                           Si
# 6                                           Si                           Si
# 7                                           Si                           Si
# 8                                           Si                           No
# 9                                           Si                           Si
# 10                                          Si                           No
# 11                                          Si                           No
# 12                                          Si                           Si
# 13                                          Si                           No
# 14                                          Si                           Si
# 15                                          Si                           Si
# 16                                          Si                           No
# 17                                          Si                           Si
# 18                                          Si                           No
# 19                                          No                           No
# 20                                          Si                           No
# 21                                          Si                           No
# 22                                          No                           No
# 23                                          Si                           Si
# 24                                          Si                           No
# 25                                          Si                           No
# 26                                          Si                           No
# 27                                          Si                           No
# 28                                          Si                           No
# 29                                          Si                           No
# 30                                          Si                           Si
# 31                                          Si                           No
# 32                                          Si                           Si
# 33                                          Si                           Si
# 34                                          Si                           Si
# 35                                          Si                           No
# 36                                          Si                           No
# 37                                          Si                           No
# 38                                          No                           No
# 39                                          Si                           Si
# 40                                          Si                           No
# 41                                          Si                           Si
# 42                                          No                           No
# 43                                          No                           No
# 44                                          Si                           No
# 45                                          Si                           No
# 46                                          Si                           Si
# 47                                          No                           No
# 48                                          Si                           No
# 49                                          Si                           No
# 50                                          Si                           No
# 51                                          Si                           No
# 52                                          Si                           No
# 53                                          Si                           No
# 54                                          Si                           No
# 55                                          Si                           No
# 56                                          Si                           No
# 57                                          Si                           No
# 58                                          Si                           No
# 59                                          Si                           No
#
#    ¿Tienes cuenta de GitHub?  edad  prog_python  usa_colab  cuenta_github
# 0                         Si    22         True      False           True
# 1                         Si    21         True      False           True
# 2                         Si    26         True       True           True
# 3                         Si    21         True       True           True
# 4                         Si    24         True      False           True
# 5                         Si    22         True       True           True
# 6                         Si    22         True       True           True
# 7                         Si    21         True       True           True
# 8                         Si    23         True      False           True
# 9                         Si    22         True       True           True
# 10                        Si    23         True      False           True
# 11                        Si    22         True      False           True
# 12                        No    23         True       True          False
# 13                        Si    22         True      False           True
# 14                        Si    22         True       True           True
# 15                        No    22         True       True          False
# 16                        Si    22         True      False           True
# 17                        Si    22         True       True           True
# 18                        Si    21         True      False           True
# 19                        Si    24        False      False           True
# 20                        Si    21         True      False           True
# 21                        Si    23         True      False           True
# 22                        Si    24        False      False           True
# 23                        Si    21         True       True           True
# 24                        Si    22         True      False           True
# 25                        Si    22         True      False           True
# 26                        Si    24         True      False           True
# 27                        Si    21         True      False           True
# 28                        No    23         True      False          False
# 29                        Si    20         True      False           True
# 30                        No    22         True       True          False
# 31                        Si    21         True      False           True
# 32                        Si    22         True       True           True
# 33                        Si    20         True       True           True
# 34                        Si    24         True       True           True
# 35                        Si    24         True      False           True
# 36                        Si    21         True      False           True
# 37                        No    25         True      False          False
# 38                        Si    23        False      False           True
# 39                        Si    23         True       True           True
# 40                        No    23         True      False          False
# 41                        Si    21         True       True           True
# 42                        No    23        False      False          False
# 43                        Si    23        False      False           True
# 44                        Si    22         True      False           True
# 45                        Si    24         True      False           True
# 46                        Si    22         True       True           True
# 47                        Si    22        False      False           True
# 48                        Si    22         True      False           True
# 49                        Si    26         True      False           True
# 50                        Si    20         True      False           True
# 51                        No    22         True      False          False
# 52                        Si    21         True      False           True
# 53                        Si    21         True      False           True
# 54                        Si    22         True      False           True
# 55                        Si    25         True      False           True
# 56                        Si    21         True      False           True
# 57                        Si    22         True      False           True
# 58                        Si    22         True      False           True
# 59                        Si    21         True      False           True

# %%
edad
# Out:
# array([22., 21., 26., 21., 24., 22., 22., 21., 23., 22., 23., 22., 23.,
#        22., 22., 22., 22., 22., 21., 24., 21., 23., 24., 21., 22., 22.,
#        24., 21., 23., 20., 22., 21., 22., 20., 24., 24., 21., 25., 23.,
#        23., 23., 21., 23., 23., 22., 24., 22., 22., 22., 26., 20., 22.,
#        21., 21., 22., 25., 21., 22., 22., 21.])

# %%
summary_age
# Out:
# {'n': 60,
#  'min': 20.0,
#  'p25': 21.0,
#  'mediana': 22.0,
#  'media': 22.3,
#  'p75': 23.0,
#  'max': 26.0,
#  'rango(ptp)': 6.0,
#  'var_muestral': 1.8406779661016948,
#  'std_muestral': 1.3567158752302173,
#  'cv': 0.06083927691615324}

# %%
print(f'Frecuencia de utilizacion de Python: {freq_python}')
print(f'Frecuencia de utilizacion de Colab: {freq_colab}')
print(f'Frecuencia de utilizacion de GitHub: {freq_gh}')
# Out:
# Frecuencia de utilizacion de Python: {'Si': 54, 'No': 6}
# Frecuencia de utilizacion de Colab: {'Si': 18, 'No': 42}
# Frecuencia de utilizacion de GitHub: {'Si': 52, 'No': 8}

# %%
print(f'Tabla 2x2 de Python y Colab: \n {tab_py_colab}')
# Out:
# Tabla 2x2 de Python y Colab:
#  [[ 6  0]
#  [36 18]]

# %%
print(f'Tabla 2x2 de Python y GitHub: \n {tab_py_gh}')
# Out:
# Tabla 2x2 de Python y GitHub:
#  [[ 1  5]
#  [ 7 47]]

# %%
# --- Configuración e importaciones ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# Tamaño y estilo de gráficos
plt.rcParams["figure.dpi"] = 160
plt.style.use('seaborn-v0_8-whitegrid')

# --- Datos crudos ---
raw = """Marca temporal	Número de matrícula	¿Cuántos años cumplidos tienes?	¿Has realizado programas utilizando Python?	¿Has utilizado Google Colab?	¿Tienes cuenta de GitHub?
19/01/2026 18:32:18	178920	22	Si	No	Si
19/01/2026 18:32:23	182712	21	Si	No	Si
19/01/2026 18:32:25	180370	26	Si	Si	Si
19/01/2026 18:32:27	182570	21	Si	Si	Si
19/01/2026 18:32:28	177622	24	Si	No	Si
19/01/2026 18:32:29	175166	22	Si	Si	Si
19/01/2026 18:32:30	177573	22	Si	Si	Si
19/01/2026 18:32:35	178430	21	Si	Si	Si
19/01/2026 18:32:38	179169	23	Si	No	Si
19/01/2026 18:32:41	177263	22	Si	Si	Si
19/01/2026 18:32:48	179884	23	Si	No	Si
19/01/2026 18:32:48	183016	22	Si	No	Si
19/01/2026 18:32:50	179033	23	Si	Si	No
19/01/2026 18:32:54	178218	22	Si	No	Si
19/01/2026 18:32:55	178446	22	Si	Si	Si
19/01/2026 18:33:00	178166	22	Si	Si	No
19/01/2026 18:33:02	177406	22	Si	No	Si
19/01/2026 18:33:05	177192	22	Si	Si	Si
19/01/2026 18:33:08	182451	21	Si	No	Si
19/01/2026 18:33:08	171513	24	No	No	Si
19/01/2026 18:33:09	181619	21	Si	No	Si
19/01/2026 18:33:12	182298	23	Si	No	Si
19/01/2026 18:33:14	181419	24	No	No	Si
19/01/2026 18:33:32	177291	21	Si	Si	Si
19/01/2026 18:33:42	182085	22	Si	No	Si
19/01/2026 18:33:53	176453	22	Si	No	Si
19/01/2026 18:34:04	176263	24	Si	No	Si
19/01/2026 18:34:06	179997	21	Si	No	Si
19/01/2026 18:36:21	175842	23	Si	No	No
19/01/2026 20:19:21	179913	20	Si	No	Si
19/01/2026 20:19:48	177301	22	Si	Si	No
19/01/2026 20:20:06	183060	21	Si	No	Si
19/01/2026 20:20:08	177935	22	Si	Si	Si
19/01/2026 20:20:19	177700	20	Si	Si	Si
19/01/2026 20:20:26	178318	24	Si	Si	Si
19/01/2026 20:20:27	174653	24	Si	No	Si
19/01/2026 20:20:29	177139	21	Si	No	Si
19/01/2026 20:20:31	173479	25	Si	No	No
19/01/2026 20:20:39	175588	23	No	No	Si
19/01/2026 20:20:45	178774	23	Si	Si	Si
19/01/2026 20:20:45	175031	23	Si	No	No
19/01/2026 20:20:49	178396	21	Si	Si	Si
19/01/2026 20:20:49	172068	23	No	No	No
19/01/2026 20:20:50	174197	23	No	No	Si
19/01/2026 20:20:55	178584	22	Si	No	Si
19/01/2026 20:20:55	175329	24	Si	No	Si
19/01/2026 20:20:56	177685	22	Si	Si	Si
19/01/2026 20:20:57	178678	22	No	No	Si
19/01/2026 20:21:04	177143	22	Si	No	Si
19/01/2026 20:21:07	182318	26	Si	No	Si
19/01/2026 20:21:27	182377	20	Si	No	Si
19/01/2026 20:21:34	179419	22	Si	No	No
19/01/2026 20:21:35	181662	21	Si	No	Si
19/01/2026 20:21:38	181760	21	Si	No	Si
19/01/2026 20:22:06	177888	22	Si	No	Si
19/01/2026 20:22:15	176535	25	Si	No	Si
19/01/2026 20:22:29	179862	21	Si	No	Si
19/01/2026 20:22:32	178378	22	Si	No	Si
19/01/2026 20:22:50	177451	22	Si	No	Si
19/01/2026 20:23:15	179804	21	Si	No	Si
"""

# --- Carga y limpieza ---
df = pd.read_csv('/content/datos.csv')
df.columns = [c.strip() for c in df.columns]

# --- Variables derivadas ---
df['edad'] = pd.to_numeric(df['¿Cuántos años cumplidos tienes?'], errors='coerce')
map_sn = {'Si': True, 'No': False}
df['prog_python'] = df['¿Has realizado programas utilizando Python?'].map(map_sn)
df['usa_colab'] = df['¿Has utilizado Google Colab?'].map(map_sn)
df['cuenta_github'] = df['¿Tienes cuenta de GitHub?'].map(map_sn)

# --- Paleta de colores ---
accent  = 'red'  # azul
accent2 = '#16a34a'  # verde
accent3 = '#f59e0b'  # ámbar
neutral = '#6b7280'  # gris

# =========================
# 1) Histograma de edades
# =========================
fig, ax = plt.subplots(figsize=(8,5))
bins = range(int(df['edad'].min())-1, int(df['edad'].max())+2)
ax.hist(df['edad'], bins=bins, color=accent, edgecolor='white', alpha=0.85)
mean_age = df['edad'].mean()
med_age = df['edad'].median()
ax.axvline(mean_age, color=accent2, linestyle='--', linewidth=2, label=f"Media: {mean_age:.2f}")
ax.axvline(med_age, color=accent3, linestyle=':', linewidth=2.5, label=f"Mediana: {med_age:.2f}")
ax.set_title('Distribución de edades')
ax.set_xlabel('Edad (años)')
ax.set_ylabel('Frecuencia')
ax.legend()
plt.tight_layout()
plt.show()
fig.savefig('01_hist_edades.png', dpi=180)

# =======================
# 2) Boxplot de edades
# =======================
fig, ax = plt.subplots(figsize=(6,4))
ax.boxplot(df['edad'], vert=False, patch_artist=True,
           boxprops=dict(facecolor=accent, color=accent),
           medianprops=dict(color='white', linewidth=2),
           whiskerprops=dict(color=accent), capprops=dict(color=accent))
ax.set_title('Caja y bigotes: edad')
ax.set_xlabel('Edad (años)')
plt.tight_layout()
plt.show()
fig.savefig('02_box_edades.png', dpi=180)

# ====================================================
# 3) Barras: frecuencias de Sí/No para Python/Colab/GitHub
# ====================================================
fig, axes = plt.subplots(1,3, figsize=(12,4), sharey=True)
for ax, col, title, color in zip(
    axes,
    ['prog_python','usa_colab','cuenta_github'],
    ['Programó en Python','Usó Google Colab','Cuenta de GitHub'],
    [accent, accent2, accent3]
):
    counts = df[col].value_counts().reindex([True, False]).fillna(0).astype(int)
    labels = ['Sí','No']
    bars = ax.bar(labels, counts, color=[color, neutral], edgecolor='white')
    ax.set_title(title)
    ax.set_ylim(0, max(counts.max(), 1)+2)
    for i, v in enumerate(counts):
        ax.text(i, v+0.1, str(v), ha='center', va='bottom', fontsize=9)
axes[0].set_ylabel('Número de estudiantes')
plt.tight_layout()
plt.show()
fig.savefig('03_barras_frecuencias.png', dpi=180)

# =======================================
# 4) Mapas de calor 2x2 para combinaciones
# =======================================
pairs = [
    ('prog_python','usa_colab','Python vs Colab'),
    ('prog_python','cuenta_github','Python vs GitHub'),
    ('usa_colab','cuenta_github','Colab vs GitHub')
]

for idx, (a,b,titulo) in enumerate(pairs, start=1):
    a_bool = df[a].to_numpy(dtype=bool)
    b_bool = df[b].to_numpy(dtype=bool)
    t = np.zeros((2,2), dtype=int)
    t[1,1] = np.count_nonzero(a_bool & b_bool)
    t[1,0] = np.count_nonzero(a_bool & ~b_bool)
    t[0,1] = np.count_nonzero(~a_bool & b_bool)
    t[0,0] = np.count_nonzero(~a_bool & ~b_bool)

    fig, ax = plt.subplots(figsize=(5,4))
    im = ax.imshow(t, cmap='Blues')
    ax.set_title(f'Tabla 2×2: {titulo}')
    ax.set_xticks([0,1]); ax.set_xticklabels(['No','Sí'])
    ax.set_yticks([0,1]); ax.set_yticklabels(['No','Sí'])
    ax.set_xlabel(b); ax.set_ylabel(a)

    for i in range(2):
        for j in range(2):
            ax.text(j, i, t[i,j], ha='center', va='center',
                    color='black', fontsize=12, fontweight='bold')

    cbar = fig.colorbar(im, ax=ax)
    cbar.ax.set_ylabel('Conteo', rotation=270, labelpad=12)
    plt.tight_layout()
    plt.show()
    fig.savefig(f'04_heatmap_{idx}.png', dpi=180)

# ======================================================
# 5) Barras: edad promedio por grupo (Sí/No) por variable
# ======================================================
fig, axes = plt.subplots(1,3, figsize=(12,4), sharey=True)
for ax, col, title, color in zip(
    axes,
    ['prog_python','usa_colab','cuenta_github'],
    ['Edad promedio por Python','Edad promedio por Colab','Edad promedio por GitHub'],
    [accent, accent2, accent3]
):
    means = df.groupby(col)['edad'].mean().reindex([True, False])
    labels = ['Sí','No']
    bars = ax.bar(labels, means, color=[color, neutral], edgecolor='white')
    for i, v in enumerate(means):
        ax.text(i, v+0.05, f"{v:.2f}", ha='center', va='bottom', fontsize=9)
    ax.set_title(title)
    ax.set_xlabel('Grupo')
axes[0].set_ylabel('Edad promedio (años)')
plt.tight_layout()
plt.show()
fig.savefig('05_barras_edad_promedio.png', dpi=180)

# ===================================
# 6) Estadísticos de edad (impresión)
# ===================================
summary_age = {
    'n': int(df['edad'].size),
    'min': float(df['edad'].min()),
    'p25': float(np.percentile(df['edad'], 25)),
    'mediana': float(df['edad'].median()),
    'media': float(df['edad'].mean()),
    'p75': float(np.percentile(df['edad'], 75)),
    'max': float(df['edad'].max()),
    'rango(ptp)': float(np.ptp(df['edad'])),
    'var_muestral': float(np.var(df['edad'], ddof=1)),
    'std_muestral': float(np.std(df['edad'], ddof=1)),
    'cv': float(np.std(df['edad'], ddof=1)/np.mean(df['edad'])),
}
summary_age
# Out:
# {'n': 60,
#  'min': 20.0,
#  'p25': 21.0,
#  'mediana': 22.0,
#  'media': 22.3,
#  'p75': 23.0,
#  'max': 26.0,
#  'rango(ptp)': 6.0,
#  'var_muestral': 1.8406779661016952,
#  'std_muestral': 1.3567158752302175,
#  'cv': 0.06083927691615325}

# %%
# =========================
# 1) Histograma de edades
# =========================
fig, ax = plt.subplots(figsize=(8,5))
bins = range(int(df['edad'].min())-1, int(df['edad'].max())+2)
ax.hist(df['edad'], bins=bins, color=accent, edgecolor='white', alpha=0.85)
mean_age = df['edad'].mean()
med_age = df['edad'].median()
ax.axvline(mean_age, color=accent2, linestyle='--', linewidth=2, label=f"Media: {mean_age:.2f}")
ax.axvline(med_age, color=accent3, linestyle=':', linewidth=2.5, label=f"Mediana: {med_age:.2f}")
ax.set_title('Distribución de edades de alumnos')
ax.set_xlabel('Edad (años)')
ax.set_ylabel('Frecuencia')
ax.legend()
plt.tight_layout()
plt.show()
fig.savefig('01_hist_edades.png', dpi=180)

# %%
# =======================
# 2) Boxplot de edades
# =======================
fig, ax = plt.subplots(figsize=(6,4))
ax.boxplot(df['edad'], vert=False, patch_artist=True,
           boxprops=dict(facecolor=accent, color=accent),
           medianprops=dict(color='white', linewidth=2),
           whiskerprops=dict(color=accent), capprops=dict(color=accent))
ax.set_title('Caja y bigotes: edad')
ax.set_xlabel('Edad (años)')
plt.tight_layout()
plt.show()
fig.savefig('02_box_edades.png', dpi=180)

# %%
# ====================================================
# 3) Barras: frecuencias de Sí/No para Python/Colab/GitHub
# ====================================================
fig, axes = plt.subplots(1,3, figsize=(12,4), sharey=True)
for ax, col, title, color in zip(
    axes,
    ['prog_python','usa_colab','cuenta_github'],
    ['Programó en Python','Usó Google Colab','Cuenta de GitHub'],
    [accent, accent2, accent3]
):
    counts = df[col].value_counts().reindex([True, False]).fillna(0).astype(int)
    labels = ['Sí','No']
    ax.bar(labels, counts, color=[color, neutral], edgecolor='white')
    ax.set_title(title)
    ax.set_ylim(0, max(counts.max(), 1)+2)
    for i, v in enumerate(counts):
        ax.text(i, v+0.1, str(v), ha='center', va='bottom', fontsize=9)
axes[0].set_ylabel('Número de estudiantes')
plt.tight_layout()
plt.show()
fig.savefig('03_barras_frecuencias.png', dpi=180)

# %%
# =======================================
# 4) Mapas de calor 2x2 para combinaciones
# =======================================
pairs = [
    ('prog_python','usa_colab','Python vs Colab'),
    ('prog_python','cuenta_github','Python vs GitHub'),
    ('usa_colab','cuenta_github','Colab vs GitHub')
]

for idx, (a,b,titulo) in enumerate(pairs, start=1):
    a_bool = df[a].to_numpy(dtype=bool)
    b_bool = df[b].to_numpy(dtype=bool)
    t = np.zeros((2,2), dtype=int)
    t[1,1] = np.count_nonzero(a_bool & b_bool)
    t[1,0] = np.count_nonzero(a_bool & ~b_bool)
    t[0,1] = np.count_nonzero(~a_bool & b_bool)
    t[0,0] = np.count_nonzero(~a_bool & ~b_bool)

    fig, ax = plt.subplots(figsize=(5,4))
    im = ax.imshow(t, cmap='Blues')
    ax.set_title(f'Tabla 2×2: {titulo}')
    ax.set_xticks([0,1]); ax.set_xticklabels(['No','Sí'])
    ax.set_yticks([0,1]); ax.set_yticklabels(['No','Sí'])
    ax.set_xlabel(b); ax.set_ylabel(a)

    for i in range(2):
        for j in range(2):
            ax.text(j, i, t[i,j], ha='center', va='center',
                    color='black', fontsize=12, fontweight='bold')

    cbar = fig.colorbar(im, ax=ax)
    cbar.ax.set_ylabel('Conteo', rotation=270, labelpad=12)
    plt.tight_layout()
    plt.show()
    fig.savefig(f'04_heatmap_{idx}.png', dpi=180)

# %%
# ======================================================
# 5) Barras: edad promedio por grupo (Sí/No) por variable
# ======================================================
fig, axes = plt.subplots(1,3, figsize=(12,4), sharey=True)
for ax, col, title, color in zip(
    axes,
    ['prog_python','usa_colab','cuenta_github'],
    ['Edad promedio por Python','Edad promedio por Colab','Edad promedio por GitHub'],
    [accent, accent2, accent3]
):
    means = df.groupby(col)['edad'].mean().reindex([True, False])
    labels = ['Sí','No']
    bars = ax.bar(labels, means, color=[color, neutral], edgecolor='white')
    for i, v in enumerate(means):
        ax.text(i, v+0.05, f"{v:.2f}", ha='center', va='bottom', fontsize=9)
    ax.set_title(title)
    ax.set_xlabel('Grupo')
axes[0].set_ylabel('Edad promedio (años)')
plt.tight_layout()
plt.show()
fig.savefig('05_barras_edad_promedio.png', dpi=180)

# %%
# ===================================
# 6) Estadísticos de edad (impresión)
# ===================================
summary_age = {
    'n': int(df['edad'].size),
    'min': float(df['edad'].min()),
    'p25': float(np.percentile(df['edad'], 25)),
    'mediana': float(df['edad'].median()),
    'media': float(df['edad'].mean()),
    'p75': float(np.percentile(df['edad'], 75)),
    'max': float(df['edad'].max()),
    'rango(ptp)': float(np.ptp(df['edad'])),
    'var_muestral': float(np.var(df['edad'], ddof=1)),
    'std_muestral': float(np.std(df['edad'], ddof=1)),
    'cv': float(np.std(df['edad'], ddof=1)/np.mean(df['edad'])),
}
summary_age
# Out:
# {'n': 60,
#  'min': 20.0,
#  'p25': 21.0,
#  'mediana': 22.0,
#  'media': 22.3,
#  'p75': 23.0,
#  'max': 26.0,
#  'rango(ptp)': 6.0,
#  'var_muestral': 1.8406779661016952,
#  'std_muestral': 1.3567158752302175,
#  'cv': 0.06083927691615325}

# %% [markdown]
# ### 1.2.2 Error Cuadrado Medio

# %% [markdown]
# MSE y Otros Indicadores

# %%
import numpy as np
import pandas as pd

# %%
anios_escolaridad = np.array([0, 3, 6, 9, 12, 16, 18])
ingreso_mensual_estimado_mx = np.array([12621, 15723, 19587, 24401, 30398, 40747, 47176])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(anios_escolaridad, ingreso_mensual_estimado_mx)
plt.title('Años de Escolaridad vs. Ingreso Mensual Estimado')
plt.xlabel('Años de Escolaridad')
plt.ylabel('Ingreso Mensual Estimado (MXN)')
plt.grid(True)
plt.show()

# %% [markdown]
# Primer intento de modelar los años de escolaridad y el ingreso estimado.
# Utilizar el primer punto y el útlimo para trazar una recta:
#
# $$ m = \frac{y_{2}-y_{1}}{x_{2}-x_{1}} $$
#
# $$ b = y_{1} - m * x_{1} $$

# %%
x1 = anios_escolaridad[0]
y1 = ingreso_mensual_estimado_mx[0]
x2 = anios_escolaridad[-1]
y2 = ingreso_mensual_estimado_mx[-1]

m = (y2 - y1) / (x2 - x1)
b = y1 - m * x1

print(f"La ecuación de la recta es: y = {m:.2f}x + {b:.2f}")
# Out:
# La ecuación de la recta es: y = 1919.72x + 12621.00

# %%
import matplotlib.pyplot as plt

# Calcular los valores y de la recta utilizando m y b
linea_ingreso_estimado_new_plot = m * anios_escolaridad + b

plt.figure(figsize=(10, 6))
plt.scatter(anios_escolaridad, ingreso_mensual_estimado_mx, label='Datos Originales')
plt.plot(anios_escolaridad, linea_ingreso_estimado_new_plot, color='red',
         label=f'Recta de Regresión (y = {m:.2f}x + {b:.2f})')
plt.title('Años de Escolaridad vs. Ingreso Mensual Estimado con Línea de Regresión')
plt.xlabel('Años de Escolaridad')
plt.ylabel('Ingreso Mensual Estimado (MXN)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Valores predichos
# : Son los ingresos mensuales que nuestra recta de regresión predice para cada año de escolaridad.
#
# Errores (residuales): Es la diferencia entre el ingreso mensual real (ingreso_mensual_estimado_mx) y el ingreso mensual predicho (y_pred). Un error positivo significa que la predicción fue menor que el valor real, y un error negativo indica que la predicción fue mayor.
#
# Errores al cuadrado: Hemos elevado al cuadrado cada uno de los errores. Esto se hace para eliminar los signos negativos (de modo que los errores positivos y negativos no se cancelen entre sí) y para penalizar más los errores grandes.
#
# Suma de errores cuadrados: Es la suma de todos los errores al cuadrado. Este valor nos da una medida total de la 'distancia' de nuestros puntos a la línea.
#
# Error Cuadrático Medio (MSE): Es la suma de los errores cuadrados dividida por el número total de puntos de datos. El MSE es una medida promedio de la magnitud de los errores. Un MSE más bajo indica que el modelo se ajusta mejor a los datos.
#
# En este caso, el Error Cuadrático Medio (MSE) es de aproximadamente 13,196,667.31. Este número nos da una idea del rendimiento general de la recta que trazamos, mostrando la magnitud promedio de los errores al cuadrado entre los valores observados y los valores predichos por la línea.
#
# Fórmula del MSE (Error Cuadrático Medio) del Inglés Mean Squared Error
#
# $$ MSE = \frac {\Sigma_{i=1}^{n}(Y_{i}-\hat{Y_{i}})^{2}}{n} $$
#
# Donde:
#  $ MSE = $ error cuadrático medio.
#  $ n = $ número de datos.
#  $ Y_{i} = $ valores observados.
#  $ \hat{Y_{i}} = $ valores predichos.

# %%
# 1. Calcular los valores predichos (y_pred) usando la ecuación de la recta
y_pred = m * anios_escolaridad + b
y_pred
# Out:
# array([12621.        , 18380.16666667, 24139.33333333, 29898.5       ,
#        35657.66666667, 43336.55555556, 47176.        ])

# %%
# 2. Calcular los errores (residuales): la diferencia entre los valores reales y los predichos
errores = ingreso_mensual_estimado_mx - y_pred
errores
# Out:
# array([    0.        , -2657.16666667, -4552.33333333, -5497.5       ,
#        -5259.66666667, -2589.55555556,     0.        ])

# %%
# 3. Elevar al cuadrado cada error
errores_cuadrados = errores**2
errores_cuadrados
# Out:
# array([       0.        ,  7060534.69444443, 20723738.77777776,
#        30222506.25      , 27664093.44444442,  6705797.97530864,
#               0.        ])

# %%
# 4. Sumar los errores cuadrados
suma_errores_cuadrados = np.sum(errores_cuadrados)
suma_errores_cuadrados
# Out:
# np.float64(92376671.14197525)

# %%
# 5. Dividir la suma de los errores cuadrados por el número de puntos para obtener el MSE
mse = suma_errores_cuadrados / len(anios_escolaridad)
mse
# Out:
# np.float64(13196667.305996465)

# %% [markdown]
# Ahora comparemos el MSE de una regresión lineal.
# Por ahora no es importante el detalle de la regrsión lineal.
# Lo importante es comparar el MSE.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
# Cambia la forma de anios_escolaridad a 2D array como es requerido por sklearn
X = anios_escolaridad.reshape(-1, 1)
y = ingreso_mensual_estimado_mx

X
# Out:
# array([[ 0],
#        [ 3],
#        [ 6],
#        [ 9],
#        [12],
#        [16],
#        [18]])

# %%
# Crear y ajustar el modelo de regresión lineal
modelo_regresion = LinearRegression()
modelo_regresion.fit(X, y)

# Obtener los coeficientes (m) e intercepto (b) del nuevo modelo
m_sklearn = modelo_regresion.coef_[0]
b_sklearn = modelo_regresion.intercept_

print(f"Coefficients (m) from scikit-learn: {m_sklearn:.2f}")
print(f"Intercept (b) from scikit-learn: {b_sklearn:.2f}")
# Out:
# Coefficients (m) from scikit-learn: 1914.55
# Intercept (b) from scikit-learn: 9731.66

# %% [markdown]
# El nuevo modelo de recta obtenido con regrsión lineal es:
#
# Como ejercicios:
#
# 1. Grafica la línea del modelo de regresión lineal de sklearn junto con los datos originales.
# 2. Calcula el MSE de esta regresión lineal y compara con el resultado anterior.
# 3. ¿Cuál recta tiene menos error con respecto a los datos originales?.
#
# Además del MSE (Error Cuadrático Medio), existen varios indicadores clave para evaluar modelos de regresión lineal, cada uno con un enfoque distinto sobre el rendimiento del modelo:
#
# - RMSE (Raíz del Error Cuadrático Medio): Es la raíz cuadrada del MSE. A diferencia del MSE, el RMSE expresa el error en las mismas unidades que la variable objetivo, lo que facilita su interpretación. Es útil para penalizar errores grandes, similar al MSE.
# - MAE (Error Absoluto Medio): Calcula el promedio de las diferencias absolutas entre las predicciones y los valores reales. Es más robusto ante valores atípicos (outliers) que el MSE, ya que no eleva al cuadrado los errores grandes.
# - $R^{2}$ (Coeficiente de Determinación): Indica qué proporción de la variación de la variable dependiente es explicada por el modelo. Va de 0 a 1; un valor más cercano a 1 indica un mejor ajuste.
# - $R^{2}$ Ajustado: Similar al
# , pero ajusta el valor según el número de predictores (variables independientes) en el modelo. Es más preciso que el
#  cuando se añaden variables innecesarias, ya que penaliza la complejidad excesiva.
# - MAPE (Error Porcentual Absoluto Medio): Mide el error en términos porcentuales, lo que facilita entender la precisión relativa del modelo (ej. "el modelo se equivoca en un 5% en promedio").
#
#
# Más ejercicios:
#
# 4. Escribe utilizando el Mark Down de Colab las fórmulas de cada uno de los indicadores mencionados arriba.
# 5. Calcula los indicadores para la regresión lineal.
#
#
# Resumen de uso:
#
# - Precisión general y sensibilidad a outliers: MAE.
# - Penalizar errores grandes: RMSE o MSE.
# - Explicación del modelo:
#  o
#  Ajustado.
# - Interpretación porcentual: MAPE.

# %% [markdown]
# -----------------

# %%
# 1. Graficar la línea del modelo de regresión lineal de sklearn junto con los datos originales.

# Calcular los valores y de la recta utilizando m_sklearn y b_sklearn
linea_ingreso_estimado_sklearn_plot = m_sklearn * anios_escolaridad + b_sklearn

plt.figure(figsize=(10, 6))
plt.scatter(anios_escolaridad, ingreso_mensual_estimado_mx, label='Datos Originales')
plt.plot(anios_escolaridad, linea_ingreso_estimado_sklearn_plot, color='green',
         label=f'Recta de Regresión SKLearn (y = {m_sklearn:.2f}x + {b_sklearn:.2f})')
plt.title('Años de Escolaridad vs. Ingreso Mensual Estimado con Línea de Regresión SKLearn')
plt.xlabel('Años de Escolaridad')
plt.ylabel('Ingreso Mensual Estimado (MXN)')
plt.grid(True)
plt.legend()
plt.show()

# %%
# 2. Calcular el MSE de esta regresión lineal y compara con el resultado anterior.

# Valores predichos por el modelo de sklearn
y_pred_sklearn = modelo_regresion.predict(X)

# Errores (residuales)
errores_sklearn = ingreso_mensual_estimado_mx - y_pred_sklearn

# Errores al cuadrado
errores_cuadrados_sklearn = errores_sklearn**2

# Suma de errores cuadrados
suma_errores_cuadrados_sklearn = np.sum(errores_cuadrados_sklearn)

# MSE del modelo de sklearn
mse_sklearn = suma_errores_cuadrados_sklearn / len(anios_escolaridad)

print(f"MSE de la regresión manual: {mse:.2f}")
print(f"MSE de la regresión con scikit-learn: {mse_sklearn:.2f}")

# 3. ¿Cuál recta tiene menos error con respecto a los datos originales?.
if mse_sklearn < mse:
    print(f"\nLa recta de regresión con scikit-learn (MSE: {mse_sklearn:.2f}) tiene menos error que la regresión manual (MSE: {mse:.2f}).")
elif mse_sklearn > mse:
    print(f"\nLa recta de regresión manual (MSE: {mse:.2f}) tiene menos error que la regresión con scikit-learn (MSE: {mse_sklearn:.2f}).")
else:
    print(f"\nAmbas rectas tienen el mismo error (MSE: {mse:.2f}).")
# Out:
# MSE de la regresión manual: 13196667.31
# MSE de la regresión con scikit-learn: 4572017.80
#
# La recta de regresión con scikit-learn (MSE: 4572017.80) tiene menos error que la regresión manual (MSE: 13196667.31).

# %% [markdown]
# ---------------------------

# %% [markdown]
# Pandas

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.339569 -0.306651  1.096629  0.576893
# 2013-01-02 -0.355532 -0.379231 -2.030265 -1.447916
# 2013-01-03 -1.054936  1.674359 -0.966125 -1.236422
# 2013-01-04 -0.912469  2.483213  0.337496  1.054019
# 2013-01-05  0.776134  0.539822 -0.915365 -1.355608
# 2013-01-06 -0.044014 -1.664522 -0.904675 -1.120208

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.339569 -0.306651  1.096629  0.576893
# 2013-01-02 -0.355532 -0.379231 -2.030265 -1.447916
# 2013-01-03 -1.054936  1.674359 -0.966125 -1.236422
# 2013-01-04 -0.912469  2.483213  0.337496  1.054019
# 2013-01-05  0.776134  0.539822 -0.915365 -1.355608

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.912469  2.483213  0.337496  1.054019
# 2013-01-05  0.776134  0.539822 -0.915365 -1.355608
# 2013-01-06 -0.044014 -1.664522 -0.904675 -1.120208

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.33956892, -0.30665097,  1.09662949,  0.57689341],
#        [-0.35553229, -0.37923114, -2.03026514, -1.44791646],
#        [-1.05493561,  1.67435855, -0.96612473, -1.2364221 ],
#        [-0.91246894,  2.48321298,  0.33749565,  1.05401929],
#        [ 0.77613354,  0.53982223, -0.9153648 , -1.35560763],
#        [-0.04401383, -1.66452163, -0.90467511, -1.12020755]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.208541  0.391165 -0.563717 -0.588207
# std    0.711419  1.506762  1.106484  1.103230
# min   -1.054936 -1.664522 -2.030265 -1.447916
# 25%   -0.773235 -0.361086 -0.953435 -1.325811
# 50%   -0.199773  0.116586 -0.910020 -1.178315
# 75%    0.243673  1.390724  0.026953  0.152618
# max    0.776134  2.483213  1.096629  1.054019

# %%
df['A'].describe()
# Out:
# count    6.000000
# mean    -0.208541
# std      0.711419
# min     -1.054936
# 25%     -0.773235
# 50%     -0.199773
# 75%      0.243673
# max      0.776134
# Name: A, dtype: float64

# %%
df_edad = pd.read_csv('/content/drive/MyDrive/datos.csv')
df_edad
# Out:
#          Marca temporal  Número de matrícula  ¿Cuántos años cumplidos tienes?  \
# 0   19/01/2026 18:32:18               178920                               22
# 1   19/01/2026 18:32:23               182712                               21
# 2   19/01/2026 18:32:25               180370                               26
# 3   19/01/2026 18:32:27               182570                               21
# 4   19/01/2026 18:32:28               177622                               24
# 5   19/01/2026 18:32:29               175166                               22
# 6   19/01/2026 18:32:30               177573                               22
# 7   19/01/2026 18:32:35               178430                               21
# 8   19/01/2026 18:32:38               179169                               23
# 9   19/01/2026 18:32:41               177263                               22
# 10  19/01/2026 18:32:48               179884                               23
# 11  19/01/2026 18:32:48               183016                               22
# 12  19/01/2026 18:32:50               179033                               23
# 13  19/01/2026 18:32:54               178218                               22
# 14  19/01/2026 18:32:55               178446                               22
# 15  19/01/2026 18:33:00               178166                               22
# 16  19/01/2026 18:33:02               177406                               22
# 17  19/01/2026 18:33:05               177192                               22
# 18  19/01/2026 18:33:08               182451                               21
# 19  19/01/2026 18:33:08               171513                               24
# 20  19/01/2026 18:33:09               181619                               21
# 21  19/01/2026 18:33:12               182298                               23
# 22  19/01/2026 18:33:14               181419                               24
# 23  19/01/2026 18:33:32               177291                               21
# 24  19/01/2026 18:33:42               182085                               22
# 25  19/01/2026 18:33:53               176453                               22
# 26  19/01/2026 18:34:04               176263                               24
# 27  19/01/2026 18:34:06               179997                               21
# 28  19/01/2026 18:36:21               175842                               23
# 29  19/01/2026 20:19:21               179913                               20
# 30  19/01/2026 20:19:48               177301                               22
# 31  19/01/2026 20:20:06               183060                               21
# 32  19/01/2026 20:20:08               177935                               22
# 33  19/01/2026 20:20:19               177700                               20
# 34  19/01/2026 20:20:26               178318                               24
# 35  19/01/2026 20:20:27               174653                               24
# 36  19/01/2026 20:20:29               177139                               21
# 37  19/01/2026 20:20:31               173479                               25
# 38  19/01/2026 20:20:39               175588                               23
# 39  19/01/2026 20:20:45               178774                               23
# 40  19/01/2026 20:20:45               175031                               23
# 41  19/01/2026 20:20:49               178396                               21
# 42  19/01/2026 20:20:49               172068                               23
# 43  19/01/2026 20:20:50               174197                               23
# 44  19/01/2026 20:20:55               178584                               22
# 45  19/01/2026 20:20:55               175329                               24
# 46  19/01/2026 20:20:56               177685                               22
# 47  19/01/2026 20:20:57               178678                               22
# 48  19/01/2026 20:21:04               177143                               22
# 49  19/01/2026 20:21:07               182318                               26
# 50  19/01/2026 20:21:27               182377                               20
# 51  19/01/2026 20:21:34               179419                               22
# 52  19/01/2026 20:21:35               181662                               21
# 53  19/01/2026 20:21:38               181760                               21
# 54  19/01/2026 20:22:06               177888                               22
# 55  19/01/2026 20:22:15               176535                               25
# 56  19/01/2026 20:22:29               179862                               21
# 57  19/01/2026 20:22:32               178378                               22
# 58  19/01/2026 20:22:50               177451                               22
# 59  19/01/2026 20:23:15               179804                               21
#
#    ¿Has realizado programas utilizando Python? ¿Has utilizado Google Colab?  \
# 0                                           Si                           No
# 1                                           Si                           No
# 2                                           Si                           Si
# 3                                           Si                           Si
# 4                                           Si                           No
# 5                                           Si                           Si
# 6                                           Si                           Si
# 7                                           Si                           Si
# 8                                           Si                           No
# 9                                           Si                           Si
# 10                                          Si                           No
# 11                                          Si                           No
# 12                                          Si                           Si
# 13                                          Si                           No
# 14                                          Si                           Si
# 15                                          Si                           Si
# 16                                          Si                           No
# 17                                          Si                           Si
# 18                                          Si                           No
# 19                                          No                           No
# 20                                          Si                           No
# 21                                          Si                           No
# 22                                          No                           No
# 23                                          Si                           Si
# 24                                          Si                           No
# 25                                          Si                           No
# 26                                          Si                           No
# 27                                          Si                           No
# 28                                          Si                           No
# 29                                          Si                           No
# 30                                          Si                           Si
# 31                                          Si                           No
# 32                                          Si                           Si
# 33                                          Si                           Si
# 34                                          Si                           Si
# 35                                          Si                           No
# 36                                          Si                           No
# 37                                          Si                           No
# 38                                          No                           No
# 39                                          Si                           Si
# 40                                          Si                           No
# 41                                          Si                           Si
# 42                                          No                           No
# 43                                          No                           No
# 44                                          Si                           No
# 45                                          Si                           No
# 46                                          Si                           Si
# 47                                          No                           No
# 48                                          Si                           No
# 49                                          Si                           No
# 50                                          Si                           No
# 51                                          Si                           No
# 52                                          Si                           No
# 53                                          Si                           No
# 54                                          Si                           No
# 55                                          Si                           No
# 56                                          Si                           No
# 57                                          Si                           No
# 58                                          Si                           No
# 59                                          Si                           No
#
#    ¿Tienes cuenta de GitHub?
# 0                         Si
# 1                         Si
# 2                         Si
# 3                         Si
# 4                         Si
# 5                         Si
# 6                         Si
# 7                         Si
# 8                         Si
# 9                         Si
# 10                        Si
# 11                        Si
# 12                        No
# 13                        Si
# 14                        Si
# 15                        No
# 16                        Si
# 17                        Si
# 18                        Si
# 19                        Si
# 20                        Si
# 21                        Si
# 22                        Si
# 23                        Si
# 24                        Si
# 25                        Si
# 26                        Si
# 27                        Si
# 28                        No
# 29                        Si
# 30                        No
# 31                        Si
# 32                        Si
# 33                        Si
# 34                        Si
# 35                        Si
# 36                        Si
# 37                        No
# 38                        Si
# 39                        Si
# 40                        No
# 41                        Si
# 42                        No
# 43                        Si
# 44                        Si
# 45                        Si
# 46                        Si
# 47                        Si
# 48                        Si
# 49                        Si
# 50                        Si
# 51                        No
# 52                        Si
# 53                        Si
# 54                        Si
# 55                        Si
# 56                        Si
# 57                        Si
# 58                        Si
# 59                        Si

# %%
df_edad = df_edad.rename(columns={'¿Cuántos años cumplidos tienes?': 'edad'})
df_edad.head()
# Out:
#         Marca temporal  Número de matrícula  edad  \
# 0  19/01/2026 18:32:18               178920    22
# 1  19/01/2026 18:32:23               182712    21
# 2  19/01/2026 18:32:25               180370    26
# 3  19/01/2026 18:32:27               182570    21
# 4  19/01/2026 18:32:28               177622    24
#
#   ¿Has realizado programas utilizando Python? ¿Has utilizado Google Colab?  \
# 0                                          Si                           No
# 1                                          Si                           No
# 2                                          Si                           Si
# 3                                          Si                           Si
# 4                                          Si                           No
#
#   ¿Tienes cuenta de GitHub?
# 0                        Si
# 1                        Si
# 2                        Si
# 3                        Si
# 4                        Si

# %%
df_edad.describe()
# Out:
#        Número de matrícula       edad
# count            60.000000  60.000000
# mean         178446.866667  22.300000
# std            2694.322817   1.356716
# min          171513.000000  20.000000
# 25%          177179.750000  21.000000
# 50%          178348.000000  22.000000
# 75%          179934.000000  23.000000
# max          183060.000000  26.000000

# %%
frecuencia_edades = df_edad['edad'].value_counts().sort_index()
display(frecuencia_edades)
# Out:
# edad
# 20     3
# 21    14
# 22    22
# 23    10
# 24     7
# 25     2
# 26     2
# Name: count, dtype: int64

# %% [markdown]
# ### 1.2.3 Escalas de Medicion

# %% [markdown]
# 1) Crea el DataFrame (o carga desde CSV si lo prefieres)

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
n = 200

df = pd.DataFrame({
"id_cliente": range(1, n+1),
"genero": np.random.choice(["F", "M", "No binario", "Prefiero no decir"], size=n, p=[0.45, 0.45, 0.05, 0.05]),
"segmento": np.random.choice(["Estándar", "Oro", "Platino"], size=n, p=[0.6, 0.3, 0.1]),
"satisfaccion": np.random.choice([1,2,3,4,5], size=n, p=[0.1,0.2,0.35,0.25,0.1]),
"ciudad": np.random.choice(["SLP", "CDMX", "GDL", "MTY", "QRO"], size=n, p=[0.35,0.25,0.15,0.15,0.10]),
"edad": np.random.normal(35, 10, size=n).round(0).clip(18, 70).astype(int),
"ingreso_mensual": np.random.lognormal(mean=9.5, sigma=0.5, size=n).round(2), # pesos MXN aprox.
"temperatura_sala": np.random.normal(23, 2, size=n).round(1),
"visitas_ultimo_anio": np.random.poisson(lam=3, size=n),
"fecha_ultima_visita": pd.to_datetime("2025-12-31") - pd.to_timedelta(np.random.randint(0, 365, size=n), unit="D")
})

df.head()
# Out:
#    id_cliente             genero  segmento  satisfaccion ciudad  edad  \
# 0           1                  F       Oro             2    SLP    27
# 1           2  Prefiero no decir  Estándar             5    SLP    40
# 2           3                  M  Estándar             3    SLP    54
# 3           4                  M       Oro             4    SLP    48
# 4           5                  F       Oro             3    SLP    51
#
#    ingreso_mensual  temperatura_sala  visitas_ultimo_anio fecha_ultima_visita
# 0         10315.01              24.0                    4          2025-04-08
# 1         27029.22              21.9                    1          2025-05-11
# 2         42169.36              23.0                    3          2025-02-14
# 3         11143.16              27.3                    4          2025-02-24
# 4         10691.98              26.5                    6          2025-03-06

# %%
df.dtypes
# Out:
# id_cliente                      int64
# genero                         object
# segmento                       object
# satisfaccion                    int64
# ciudad                         object
# edad                            int64
# ingreso_mensual               float64
# temperatura_sala              float64
# visitas_ultimo_anio             int64
# fecha_ultima_visita    datetime64[ns]
# dtype: object

# %% [markdown]
# 2) Tipado correcto por escala

# %%
# Nominal → category (sin orden)
df["genero"] = df["genero"].astype("category")
df["ciudad"] = df["ciudad"].astype("category")

# Ordinal → category con orden
segmento_cat = pd.CategoricalDtype(categories=["Estándar", "Oro", "Platino"], ordered=True)
df["segmento"] = df["segmento"].astype(segmento_cat)

satisfaccion_cat = pd.CategoricalDtype(categories=[1,2,3,4,5], ordered=True)
df["satisfaccion"] = df["satisfaccion"].astype(satisfaccion_cat)

# Intervalo / Razón → numérico (ya están), pero verifica:
df["temperatura_sala"] = pd.to_numeric(df["temperatura_sala"])
df["edad"] = pd.to_numeric(df["edad"])
df["ingreso_mensual"] = pd.to_numeric(df["ingreso_mensual"])
df["visitas_ultimo_anio"] = pd.to_numeric(df["visitas_ultimo_anio"])

# Derivada útil: días desde última visita (razón)
df["dias_desde_ultima_visita"] = (pd.to_datetime("2025-12-31") - df["fecha_ultima_visita"]).dt.days

# %%
df.dtypes
# Out:
# id_cliente                           int64
# genero                            category
# segmento                          category
# satisfaccion                      category
# ciudad                            category
# edad                                 int64
# ingreso_mensual                    float64
# temperatura_sala                   float64
# visitas_ultimo_anio                  int64
# fecha_ultima_visita         datetime64[ns]
# dias_desde_ultima_visita             int64
# dtype: object

# %% [markdown]
# 3) Análisis descriptivo apropiado según escala
# Nominal (frecuencias y proporciones):

# %%
freq_genero = df["genero"].value_counts().to_frame("frecuencia")
prop_genero = df["genero"].value_counts(normalize=True).round(3).to_frame("proporcion")
tabla_genero = freq_genero.join(prop_genero)
tabla_genero
# Out:
#                    frecuencia  proporcion
# genero
# F                          96       0.480
# M                          85       0.425
# No binario                 11       0.055
# Prefiero no decir           8       0.040

# %% [markdown]
# Ordinal (distribución y tendencia central robusta — mediana):

# %%
dist_satisfaccion = df["satisfaccion"].value_counts().sort_index().to_frame("frecuencia")
mediana_satisfaccion = df["satisfaccion"].astype(int).median() # convertir para calcular
dist_segmento = df["segmento"].value_counts().sort_index().to_frame("frecuencia")
mediana_satisfaccion, dist_satisfaccion, dist_segmento
# Out:
# (3.0,
#                frecuencia
#  satisfaccion
#  1                     23
#  2                     33
#  3                     71
#  4                     43
#  5                     30,
#            frecuencia
#  segmento
#  Estándar         113
#  Oro               68
#  Platino           19)

# %% [markdown]
# Intervalo (media, desviación, pero cuidado con cero):

# %%
temp_stats = df["temperatura_sala"].agg(["mean", "std", "min", "max"]).round(2)
temp_stats
# Out:
# mean    23.18
# std      2.07
# min     17.20
# max     27.90
# Name: temperatura_sala, dtype: float64

# %% [markdown]
# Razón (media, mediana, IQR, coeficiente de variación):

# %%
def resumen_razon(s):
    return pd.Series({
    "n": s.count(),
    "media": s.mean(),
    "mediana": s.median(),
    "sd": s.std(),
    "min": s.min(),
    "q1": s.quantile(0.25),
    "q3": s.quantile(0.75),
    "max": s.max(),
    "cv": s.std()/s.mean() if s.mean()!=0 else np.nan
    }).round(2)

razon_stats = pd.concat({
    "edad": resumen_razon(df["edad"]),
    "ingreso_mensual": resumen_razon(df["ingreso_mensual"]),
    "visitas_ultimo_anio": resumen_razon(df["visitas_ultimo_anio"]),
    "dias_desde_ultima_visita": resumen_razon(df["dias_desde_ultima_visita"])
    }, axis=1)
razon_stats
# Out:
#            edad  ingreso_mensual  visitas_ultimo_anio  \
# n        200.00           200.00               200.00
# media     35.05         16258.11                 2.96
# mediana   35.00         14682.74                 3.00
# sd         9.61          8223.99                 1.68
# min       18.00          3976.11                 0.00
# q1        29.00         10201.25                 2.00
# q3        41.25         19436.38                 4.00
# max       61.00         47262.21                 8.00
# cv         0.27             0.51                 0.57
#
#          dias_desde_ultima_visita
# n                          200.00
# media                      188.99
# mediana                    176.50
# sd                         106.72
# min                          4.00
# q1                         100.75
# q3                         283.25
# max                        364.00
# cv                           0.56

# %% [markdown]
# 4) Visualizaciones adecuadas por escala (opcional)

# %%
import matplotlib.pyplot as plt

# Nominal: barras
df["ciudad"].value_counts().plot(kind="bar", title="Frecuencia por ciudad")
plt.xlabel("Ciudad"); plt.ylabel("Frecuencia"); plt.show()

# Ordinal: barra ordenada por categorías
df["satisfaccion"].value_counts().sort_index().plot(kind="bar", title="Distribución de satisfacción (Likert)")
plt.xlabel("Puntaje"); plt.ylabel("Frecuencia"); plt.show()

# Intervalo: histograma de temperatura
df["temperatura_sala"].plot(kind="hist", bins=12, title="Histograma de temperatura (°C)")
plt.xlabel("°C"); plt.show()

# Razón: boxplot de ingreso (suele ser asimétrico)
df[["ingreso_mensual"]].plot(kind="box", title="Boxplot de ingreso mensual (MXN)")
plt.show()

# %%
q3 = df["ingreso_mensual"].quantile(0.75)
q1 = df["ingreso_mensual"].quantile(0.25)
iqr = q3 - q1
limite = q3 + 1.5 * iqr
print(limite)
limite

limite_inferior = q1 - 1.5 * iqr
print(limite_inferior)
# Out:
# 33289.05875
# -3651.4312499999996

# %% [markdown]
# 5) Cruces y análisis según escala

# %%
# Ordinal × Ordinal: asociación ordinal (p. ej., tendencia entre segmento y satisfaccion).
# Nominal × Nominal
ct_ciudad_genero = pd.crosstab(df["ciudad"], df["genero"], normalize="index").round(3)
ct_ciudad_genero

# Ordinal × Razón (grupos por segmento)
ingreso_por_segmento = df.groupby("segmento")["ingreso_mensual"].agg(["count","median","mean","std"]).round(2)
ingreso_por_segmento

# Ordinal × Ordinal: correlación de Spearman entre satisfacción y segmento
spearman = df.assign(
satisfaccion_num = df["satisfaccion"].astype(int),
segmento_num = df["segmento"].cat.codes + 1 # Estándar=1, Oro=2, Platino=3
)[["satisfaccion_num","segmento_num"]].corr(method="spearman").iloc[0,1]
spearman
# Out:
# /tmp/ipython-input-2583011555.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ingreso_por_segmento = df.groupby("segmento")["ingreso_mensual"].agg(["count","median","mean","std"]).round(2)
# np.float64(-0.040233892283196265)

# %% [markdown]
# Reto adicional
# - Crea una variable binaria: alto_ingreso = ingreso_mensual >= Q3. (Nominal dicotómica)
# - Compara la distribución de satisfacción entre alto_ingreso=True/False con un gráfico de barras apiladas.
# - Calcula días_desde_ultima_visita por segmento y evalúa si hay tendencia.

# %%
Q3 = df["ingreso_mensual"].quantile(0.75)
df["alto_ingreso"] = (df["ingreso_mensual"] >= Q3).astype("category")

# Barras apiladas: satisfacción x alto_ingreso
tabla = pd.crosstab(df["satisfaccion"], df["alto_ingreso"], normalize="columns").round(3)
tabla.plot(kind="bar", stacked=True, title="Satisfacción por alto ingreso")
plt.xlabel("Satisfacción (Likert)"); plt.ylabel("Proporción"); plt.show()

# Tendencia en días desde última visita por segmento
dias_seg = df.groupby("segmento")["dias_desde_ultima_visita"].median()
dias_seg
# Out:
# /tmp/ipython-input-3547524051.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dias_seg = df.groupby("segmento")["dias_desde_ultima_visita"].median()
# segmento
# Estándar    171.0
# Oro         189.0
# Platino     183.0
# Name: dias_desde_ultima_visita, dtype: float64

# %%
Q3
# Out:
# np.float64(19436.375)

# %%
df["ingreso_mensual"] >= Q3
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: ingreso_mensual, Length: 200, dtype: bool

# %% [markdown]
# Preguntas guía para el informe
# **¿Qué variables son nominales, ordinales, de intervalo y de razón?    Da justificación breve.**
#
#   Nominales: prog_python, usa_colab, cuenta_github. Justificación: Son categorías de "Sí/No" sin un orden inherente.
#
#   Ordinales: satisfaccion. Justificación: Representa niveles de satisfacción que sí tienen un orden (de menos a más), aunque la distancia entre niveles no sea exacta.
#
#   De Razón: edad, ingreso_mensual. Justificación: Son valores numéricos donde el cero indica ausencia de la variable y se pueden realizar operaciones matemáticas.
#
# **¿Qué medidas resumen usaste para cada tipo y por qué?**
#
#   Para variables cualitativas (Nominales/Ordinales): Se usaron frecuencias y porcentajes (tablas de frecuencia). Se eligen porque permiten ver la proporción de personas en cada categoría.
#
#   Para variables cuantitativas (De Razón): Se usaron la media, mediana, desviación estándar y cuartiles. La media da el promedio, la mediana el centro de los datos sin verse afectada por valores extremos, y la desviación estándar mide qué tan dispersos están los datos.
#
# **¿Qué hallazgos obtuviste al cruzar segmento con ingreso_mensual y con satisfaccion? **
#
#   Al cruzar segmento con ingreso_mensual, se observa cómo varía la capacidad económica según el perfil del usuario.
#
#   Al cruzar segmento con satisfaccion, se identifica qué grupos están más conformes con el servicio, lo que ayuda a detectar qué segmentos necesitan más atención o mejoras.
#
# **¿Hay asimetría notable en ingreso_mensual? ¿Cómo la trataste?**
#
#   ¿Hay asimetría? Sí, generalmente el ingreso mensual presenta una asimetría positiva (la mayoría gana menos y pocos ganan mucho).
#
#   Tratamiento: Se analizó comparando la media con la mediana. Si la media es mucho mayor que la mediana, confirma la asimetría. También se suelen usar diagramas de caja (boxplots) para visualizar los valores extremos.
#
# **¿Qué recomendarías al negocio con base en los resultados?**
#
# Focalización: Dirigir campañas específicas a los segmentos con menor satisfacción para evitar que abandonen el servicio.
#
# Estrategia de Precios: Ajustar ofertas o niveles de servicio basados en los rangos de ingreso detectados en cada segmento.
#
# Capacitación: Dado que muchos usuarios programan en Python pero pocos usan herramientas avanzadas como Colab, se recomienda ofrecer talleres de estas herramientas para aumentar el valor percibido.

# %% [markdown]
# ### 1.2.4 Correlacion

# %% [markdown]
# Teoría de la Correlación en Minería de Datos

# %% [markdown]
# La correlación es una herramienta estadística fundamental para entender cómo se relacionan dos variables. Se utiliza en minería de datos, machine learning, análisis exploratorio y ciencia de datos para identificar patrones, dependencias, redundancias, multicolinealidad y posibles causas subyacentes.

# %% [markdown]
# 1. ¿Qué es la correlación?

# %% [markdown]
# La correlación mide la fuerza y la dirección de la relación entre dos variables numéricas.
#
# Dirección: positiva o negativa
# Fuerza: débil, moderada o fuerte
# Tipo de relación: lineal o monótona (no necesariamente lineal)
# La correlación NO implica causalidad, pero sí puede ser indicio útil para plantear hipótesis, modelar variables o detectar redundancias.

# %% [markdown]
# 2. Signo y magnitud de la correlación

# %% [markdown]
# Dirección
# Positiva (r > 0): cuando una variable aumenta, la otra también.
# Negativa (r < 0): cuando una variable aumenta, la otra disminuye.
# Cero (r = 0): no hay relación lineal observable.
# Magnitud (reglas generales)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Tipos de correlación
# 🔹 3.1. Correlación de Pearson (r)

# %% [markdown]
# Mide la relación lineal entre dos variables continuas.
#
# Supuestos:
# Relación aproximadamente lineal
# Variables continuas
# Sin outliers extremos (muy sensibles)
# Aproximadamente normales
# ¿Cuándo usarla?
# Cuando la gráfica de dispersión sugiere linealidad.
# Cuando estás construyendo modelos lineales, regresión múltiple o PCA.

# %% [markdown]
# 3.2. Correlación de Spearman (ρ)

# %% [markdown]
# Mide la relación monótona, usando el rango de los datos.
#
# Características:
# No requiere normalidad
# Mucho más robusta a outliers
# Funciona bien con variables ordinales
# Captura relaciones monótonas no lineales
# ¿Cuándo usarla?
# Cuando la relación no es lineal pero sí monótona (creciente o decreciente).
# Cuando hay outliers o datos muy sesgados.

# %% [markdown]
# 3.3. Correlación de Kendall (τ)

# %% [markdown]
# Basada en pares concordantes y discordantes entre dos variables.
#
# Características:
# Más robusta que Spearman
# Ideal para datos ordinales
# Más interpretativa cuando hay empates
# ¿Cuándo usarla?
# Con datasets pequeños
# Con valores ordinales
# Cuando se quiere comparar la probabilidad de que dos observaciones mantengan el mismo orden

# %% [markdown]
# 4. Visualización de relaciones

# %% [markdown]
# Antes de calcular correlaciones, SIEMPRE se recomienda visualizar.
#
# Herramientas:
# Scatter plots: para evaluar linealidad
# Pairplots: relaciones múltiples
# Heatmaps: matrices de correlación
# Diagramas de cajas: detectar outliers

# %% [markdown]
# 5. Factores que distorsionan la correlación

# %% [markdown]
# 5.1 Outliers
# Pueden aumentar o disminuir drásticamente la correlación de Pearson.
# Spearman y Kendall son más resistentes.
# 5.2 No linealidad
# Variables pueden tener relación curvilínea (ej.: U invertida) con r ≈ 0.
#
# Ejemplo clásico:
#
# relación entre rendimiento y cantidad de entrenamiento
# Podría ser fuerte, pero no lineal → Pearson falla.
# 5.3 Heterocedasticidad
# Si la dispersión aumenta con la variable:
#
# Pearson pierde fiabilidad
# Puede ser necesario transformar datos (log, box-cox)

# %% [markdown]
# 6. Correlación ≠ causalidad

# %% [markdown]
# Este es uno de los errores más comunes.
#
# Una correlación NO significa causalidad debido a:
# Coincidencia aleatoria
# Causa inversa
# Variable oculta o confusora (spurious correlation)
# Relación no causal pero asociada por un tercer fenómeno
# Ejemplo clásico:
#
# Helados y ahogamientos correlacionan
# Causa común: el calor del verano

# %% [markdown]
# 7. Correlación en minería de datos y machine learning

# %% [markdown]
# Usos comunes
# Selección de características (Feature Selection)
# Detección de multicolinealidad
# Ingeniería de variables
# Evaluación de dependencia
# Análisis exploratorio previo al modelado

# %% [markdown]
# 8. Multicolinealidad

# %% [markdown]
# En modelos que dependen de relaciones lineales (regresión, GLM), si dos variables están muy correlacionadas:
#
# Inflan los errores estándar
# Dificultan la interpretación
# Causan inestabilidad numérica
# Indicador más usado:
# VIF (Variance Inflation Factor)
#
# VIF > 5 → sospechoso
# VIF > 10 → problemática seria

# %% [markdown]
# 9. Correlación parcial

# %% [markdown]
# Mide la correlación entre X e Y controlando el efecto de una tercera variable Z.
#
# 📌 Útil para distinguir relaciones “reales” de las que solo existen por un confusor.

# %% [markdown]
# 10. Correlación con variables categóricas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.3 Probabilidad Condicional

# %% [markdown]
# 1. ¿Qué es la probabilidad condicional?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Ejemplo básico

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Ejemplo más interesante

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Arbol de Probabilidad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ejercicios de probabilidad condicional

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Segundo Parcial
